# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
print("hello world")
# Out:
# hello world

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
df["overall"].max()
# Out:
# 93

# %%
df["overall"].min()
# Out:
# 47

# %%
df[df["overall"]==47]
# Out:
#        sofifa_id                                         player_url  \
# 19220     243725  https://sofifa.com/player/243725/darren-collin...
# 19221     243790  https://sofifa.com/player/243790/zhenao-wang/2...
# 19222     245024  https://sofifa.com/player/245024/shilong-wang/...
# 19223     255615  https://sofifa.com/player/255615/xinfeng-fang/...
# 19224     257687  https://sofifa.com/player/257687/xingyu-hu/220002
# 19225     259213  https://sofifa.com/player/259213/dylan-da-silv...
# 19226     259219  https://sofifa.com/player/259219/nestor-dias/2...
# 19227     259646  https://sofifa.com/player/259646/arsh-shaikh/2...
# 19228     259650  https://sofifa.com/player/259650/fardin-ali-mo...
# 19229     259737  https://sofifa.com/player/259737/haobam-singh/...
# 19230     260398  https://sofifa.com/player/260398/nathan-dylan-...
# 19231     261547  https://sofifa.com/player/261547/revanth-by/22...
# 19232     261667  https://sofifa.com/player/261667/matthew-obrie...
# ...

# %%
df[df["overall"] > 90]
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5     200389  https://sofifa.com/player/200389/jan-oblak/220002
# 6     231747  https://sofifa.com/player/231747/kylian-mbappe...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
# ...

# %%
df['player_positions']
# Out:
# 0        RW, ST, CF
# 1                ST
# 2            ST, LW
# 3           LW, CAM
# 4           CM, CAM
#             ...
# 19234           CDM
# 19235            CM
# 19236            CM
# 19237            ST
# 19238           CAM
# Name: player_positions, Length: 19239, dtype: object

# %%
list(df['short_name'])[25]
# Out:
# 'R. Lukaku'

# %%
list(df['short_name'])[25].upper()
# Out:
# 'R. LUKAKU'

# %%
df['player_attribute'] = df['player_positions'].str[0:2]

# %%
df['player_attribute']
# Out:
# 0        RW
# 1        ST
# 2        ST
# 3        LW
# 4        CM
#          ..
# 19234    CD
# 19235    CM
# 19236    CM
# 19237    ST
# 19238    CA
# Name: player_attribute, Length: 19239, dtype: object

# %%
df.sort_values(by=['wage_eur'], ascending = False)
# Out:
#        sofifa_id                                         player_url  \
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 11        165153  https://sofifa.com/player/165153/karim-benzema...
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 14        200145  https://sofifa.com/player/200145/carlos-henriq...
# 24        182521  https://sofifa.com/player/182521/toni-kroos/22...
# ...          ...                                                ...
# 12269     183122  https://sofifa.com/player/183122/birkir-mar-sa...
# 12891     245685  https://sofifa.com/player/245685/onni-valakari...
# 14199     259680  https://sofifa.com/player/259680/marko-stameni...
# 14466     213094  https://sofifa.com/player/213094/storm-roux/22...
# 14654     241475  https://sofifa.com/player/241475/pyry-soiri/22...
#
#          short_name                          long_name player_positions  \
# 4      K. De Bruyne                    Kevin De Bruyne          CM, CAM
# ...

# %%
df["wage_to_val_ratio"] = df['wage_eur']/df['value_eur']

# %%
#creating new df with needed columns
df1 = df[['short_name', 'overall', 'wage_to_val_ratio', 'wage_eur', 'value_eur']]

# %%
df1.head()
# Out:
#           short_name  overall  wage_to_val_ratio  wage_eur    value_eur
# 0           L. Messi       93           0.004103  320000.0   78000000.0
# 1     R. Lewandowski       92           0.002259  270000.0  119500000.0
# 2  Cristiano Ronaldo       91           0.006000  270000.0   45000000.0
# 3          Neymar Jr       91           0.002093  270000.0  129000000.0
# 4       K. De Bruyne       91           0.002789  350000.0  125500000.0

# %%
print("shape of dataset: ", df.shape)
print("Index of dataset: ", df. index)
# Out:
# shape of dataset:  (19239, 110)
# Index of dataset:  RangeIndex(start=0, stop=19239, step=1)

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
print(df['long_name'].head())
print(type(df['long_name'].head()))
# Out:
# 0         Lionel Andrés Messi Cuccittini
# 1                     Robert Lewandowski
# 2    Cristiano Ronaldo dos Santos Aveiro
# 3          Neymar da Silva Santos Júnior
# 4                        Kevin De Bruyne
# Name: long_name, dtype: object
# <class 'pandas.core.series.Series'>

# %%
#loading new weather dataset to use datetime operations
weather_df = pd.read_csv("C:/Users/prana/OneDrive/Desktop/Data_engineering/weather_2012.csv")

# %%
weather_df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
weather_df['Date/Time'].head(10)
# Out:
# 0   2012-01-01 00:00:00
# 1   2012-01-01 01:00:00
# 2   2012-01-01 02:00:00
# 3   2012-01-01 03:00:00
# 4   2012-01-01 04:00:00
# 5   2012-01-01 05:00:00
# 6   2012-01-01 06:00:00
# 7   2012-01-01 07:00:00
# 8   2012-01-01 08:00:00
# 9   2012-01-01 09:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %%
#changing from object to datetime
weather_df['Date/Time'] = pd.to_datetime(weather_df['Date/Time'])

# %%
weather_df['Date/Time'].head(10)
# Out:
# 0   2012-01-01 00:00:00
# 1   2012-01-01 01:00:00
# 2   2012-01-01 02:00:00
# 3   2012-01-01 03:00:00
# 4   2012-01-01 04:00:00
# 5   2012-01-01 05:00:00
# 6   2012-01-01 06:00:00
# 7   2012-01-01 07:00:00
# 8   2012-01-01 08:00:00
# 9   2012-01-01 09:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %%
weather_df['Weather']
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object

# %%
#unsing .unique() on both datasets
print('weathers are of types: ', weather_df['Weather'].unique())
print("player ratings range in: ", df['overall'].unique())
# Out:
# weathers are of types:  ['Fog' 'Freezing Drizzle,Fog' 'Mostly Cloudy' 'Cloudy' 'Rain'
#  'Rain Showers' 'Mainly Clear' 'Snow Showers' 'Snow' 'Clear'
#  'Freezing Rain,Fog' 'Freezing Rain' 'Freezing Drizzle' 'Rain,Snow'
#  'Moderate Snow' 'Freezing Drizzle,Snow' 'Freezing Rain,Snow Grains'
#  'Snow,Blowing Snow' 'Freezing Fog' 'Haze' 'Rain,Fog' 'Drizzle,Fog'
#  'Drizzle' 'Freezing Drizzle,Haze' 'Freezing Rain,Haze' 'Snow,Haze'
#  'Snow,Fog' 'Snow,Ice Pellets' 'Rain,Haze' 'Thunderstorms,Rain'
#  'Thunderstorms,Rain Showers' 'Thunderstorms,Heavy Rain Showers'
#  'Thunderstorms,Rain Showers,Fog' 'Thunderstorms' 'Thunderstorms,Rain,Fog'
#  'Thunderstorms,Moderate Rain Showers,Fog' 'Rain Showers,Fog'
#  'Rain Showers,Snow Showers' 'Snow Pellets' 'Rain,Snow,Fog'
#  'Moderate Rain,Fog' 'Freezing Rain,Ice Pellets,Fog'
#  'Drizzle,Ice Pellets,Fog' 'Drizzle,Snow' 'Rain,Ice Pellets'
#  'Drizzle,Snow,Fog' 'Rain,Snow Grains' 'Rain,Snow,Ice Pellets'
# ...

# %%
df['overall'].value_counts()
# Out:
# 65    1251
# 67    1195
# 64    1188
# 66    1137
# 63    1127
# 68    1069
# 62    1023
# 69     939
# 70     872
# 60     783
# 61     775
# 71     766
# 72     733
# 73     665
# 59     553
# 75     503
# 58     491
# 74     462
# 57     439
# 56     362
# 55     336
# 76     328
# 54     293
# 77     273
# 53     232
# 52     209
# 78     200
# 79     154
# 51     136
# 80     121
# 81     104
# 50      97
# 82      85
# 49      75
# 83      59
# 48      45
# 84      43
# 85      28
# 86      22
# 47      19
# 87      17
# 89      11
# 88       8
# 91       5
# 90       4
# 92       1
# 93       1
# Name: overall, dtype: int64

# %%
weather_df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#value count for Snow
weather_df['Weather'].value_counts()['Snow']
# Out:
# 390

# %%
#number of times when the wind speed was exactly 4 km/h
weather_df['Wind Spd (km/h)'].value_counts()[4]
# Out:
# 474

# %%
#data manulation and transformation
col = df['short_name']
print(type(col))
col.head()
# Out:
# <class 'pandas.core.series.Series'>
# 0             L. Messi
# 1       R. Lewandowski
# 2    Cristiano Ronaldo
# 3            Neymar Jr
# 4         K. De Bruyne
# Name: short_name, dtype: object

# %%
#gettig multiple columns
two_cols = df[['short_name', 'player_positions']]
print(type(two_cols))
two_cols.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#           short_name player_positions
# 0           L. Messi       RW, ST, CF
# 1     R. Lewandowski               ST
# 2  Cristiano Ronaldo           ST, LW
# 3          Neymar Jr          LW, CAM
# 4       K. De Bruyne          CM, CAM

# %%
#slicing to get an x amount of rows
df[:20]
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      188545  https://sofifa.com/player/188545/robert-lewand...
# 2       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3      190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5      200389  https://sofifa.com/player/200389/jan-oblak/220002
# 6      231747  https://sofifa.com/player/231747/kylian-mbappe...
# 7      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8      192448  https://sofifa.com/player/192448/marc-andre-te...
# 9      202126  https://sofifa.com/player/202126/harry-kane/22...
# 10     215914  https://sofifa.com/player/215914/ngolo-kante/2...
# 11     165153  https://sofifa.com/player/165153/karim-benzema...
# 12     192119  https://sofifa.com/player/192119/thibaut-court...
# ...

# %%
df[0:20:2]
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 2       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 4      192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6      231747  https://sofifa.com/player/231747/kylian-mbappe...
# 8      192448  https://sofifa.com/player/192448/marc-andre-te...
# 10     215914  https://sofifa.com/player/215914/ngolo-kante/2...
# 12     192119  https://sofifa.com/player/192119/thibaut-court...
# 14     200145  https://sofifa.com/player/200145/carlos-henriq...
# 16     208722  https://sofifa.com/player/208722/sadio-mane/22...
# 18     210257  https://sofifa.com/player/210257/ederson-santa...
#
#            short_name                            long_name player_positions  \
# 0            L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 2   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# ...

# %%
df[0:20:2][['short_name', 'player_positions']]
# Out:
#            short_name player_positions
# 0            L. Messi       RW, ST, CF
# 2   Cristiano Ronaldo           ST, LW
# 4        K. De Bruyne          CM, CAM
# 6           K. Mbappé           ST, LW
# 8       M. ter Stegen               GK
# 10           N. Kanté          CDM, CM
# 12        T. Courtois               GK
# 14           Casemiro              CDM
# 16            S. Mané               LW
# 18            Ederson               GK

# %%
#.loc() and .iloc()
df.loc[0:5, ['value_eur', 'potential']]
# Out:
#      value_eur  potential
# 0   78000000.0         93
# 1  119500000.0         92
# 2   45000000.0         91
# 3  129000000.0         91
# 4  125500000.0         91
# 5  112000000.0         93

# %%
df[['value_eur', 'potential']].iloc[0:5]
# Out:
#      value_eur  potential
# 0   78000000.0         93
# 1  119500000.0         92
# 2   45000000.0         91
# 3  129000000.0         91
# 4  125500000.0         91

# %%
#players that can play as a winger
wing_filter = df['player_positions'].str.contains('W')

# %%
df[wing_filter]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 6         231747  https://sofifa.com/player/231747/kylian-mbappe...
# 13        200104  https://sofifa.com/player/200104/heung-min-son...
# ...          ...                                                ...
# 19180     252332  https://sofifa.com/player/252332/wei-zhang/220002
# 19184     255553  https://sofifa.com/player/255553/seong-yoon-kw...
# 19209     261957  https://sofifa.com/player/261957/keweser-xamix...
# 19214     262034  https://sofifa.com/player/262034/robbie-mahon/...
# 19221     243790  https://sofifa.com/player/243790/zhenao-wang/2...
#
#               short_name                            long_name  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
#get indexes with value as 'True'
wing_filter
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 19234    False
# 19235    False
# 19236    False
# 19237    False
# 19238    False
# Name: player_positions, Length: 19239, dtype: bool

# %%
df['short_name'].iloc[2]
# Out:
# 'Cristiano Ronaldo'

# %%
#series operations eg: addition
df['potential'].head() + 2
# Out:
# 0    95
# 1    94
# 2    93
# 3    93
# 4    93
# Name: potential, dtype: int64

# %%
weather_df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
#creating new colun for temprature in Kelvin
weather_df['Temp_K'] = weather_df['Temp (C)'] + 273.15

# %%
weather_df.head()
# Out:
#             Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0 2012-01-01 00:00:00      -1.8                -3.9           86
# 1 2012-01-01 01:00:00      -1.8                -3.7           87
# 2 2012-01-01 02:00:00      -1.8                -3.4           89
# 3 2012-01-01 03:00:00      -1.5                -3.2           88
# 4 2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather  \
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog
#
#    Temp_K
# 0  271.35
# 1  271.35
# 2  271.35
# 3  271.65
# 4  271.65

# %%
weather_df['Temp_K']
# Out:
# 0       271.35
# 1       271.35
# 2       271.35
# 3       271.65
# 4       271.65
#          ...
# 8779    273.25
# 8780    273.35
# 8781    272.65
# 8782    272.95
# 8783    273.15
# Name: Temp_K, Length: 8784, dtype: float64

# %%
weather_df[['Date/Time','Temp_K','Temp (C)']].iloc[0:5]
# Out:
#             Date/Time  Temp_K  Temp (C)
# 0 2012-01-01 00:00:00  271.35      -1.8
# 1 2012-01-01 01:00:00  271.35      -1.8
# 2 2012-01-01 02:00:00  271.35      -1.8
# 3 2012-01-01 03:00:00  271.65      -1.5
# 4 2012-01-01 04:00:00  271.65      -1.5

# %%
weather_df['Temp_K'].value_counts()[273.15]
# Out:
# 20

# %%
#working with .apply()

#creating a function to see the players value pre-covid to know how inflation(8.2%) afected club football
def value_3_years_ago(value):
    return value*((100-8.2)/100)

df['pre_covid_value_eur'] = df['value_eur'].apply(value_3_years_ago)

# %%
df[['pre_covid_value_eur', 'value_eur', 'short_name']]
# Out:
#        pre_covid_value_eur    value_eur          short_name
# 0               71604000.0   78000000.0            L. Messi
# 1              109701000.0  119500000.0      R. Lewandowski
# 2               41310000.0   45000000.0   Cristiano Ronaldo
# 3              118422000.0  129000000.0           Neymar Jr
# 4              115209000.0  125500000.0        K. De Bruyne
# ...                    ...          ...                 ...
# 19234              64260.0      70000.0           Song Defu
# 19235             100980.0     110000.0           C. Porter
# 19236              91800.0     100000.0            N. Logue
# 19237             100980.0     110000.0           L. Rudden
# 19238             100980.0     110000.0  E. Lalchhanchhuaha
#
# [19239 rows x 3 columns]

# %%
#working with .describe() by describing 'potential' column
df['potential'].describe()
# Out:
# count    19239.000000
# mean        71.079370
# std          6.086213
# min         49.000000
# 25%         67.000000
# 50%         71.000000
# 75%         75.000000
# max         95.000000
# Name: potential, dtype: float64

# %%
df.rename(columns={'value_eur':'current_value_eur'}, inplace=True)
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential  current_value_eur  wage_eur  age  ...    cb   rcb  \
# ...

# %%
df_new=df.drop(labels=['player_url','player_face_url','club_logo_url','nation_logo_url','club_flag_url','nation_flag_url'], axis=1)

# %%
df_new.head()
# Out:
#    sofifa_id         short_name                            long_name  \
# 0     158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1     188545     R. Lewandowski                   Robert Lewandowski
# 2      20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 3     190871          Neymar Jr        Neymar da Silva Santos Júnior
# 4     192985       K. De Bruyne                      Kevin De Bruyne
#
#   player_positions  overall  potential  current_value_eur  wage_eur  age  \
# 0       RW, ST, CF       93         93         78000000.0  320000.0   34
# 1               ST       92         92        119500000.0  270000.0   32
# 2           ST, LW       91         91         45000000.0  270000.0   36
# 3          LW, CAM       91         91        129000000.0  270000.0   29
# 4          CM, CAM       91         91        125500000.0  350000.0   30
#
#           dob  ...   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# ...

# %%
weather_df['Date/Time'] = pd.to_datetime(weather_df['Date/Time'])
weather_df['Date/Time'].head()
# Out:
# 0   2012-01-01 00:00:00
# 1   2012-01-01 01:00:00
# 2   2012-01-01 02:00:00
# 3   2012-01-01 03:00:00
# 4   2012-01-01 04:00:00
# Name: Date/Time, dtype: datetime64[ns]

# %%
#pivot_table(): creatig a pivot table for weather_df to get mean temp in each month
import numpy as np
mean_temperature_df = weather_df.pivot_table(values='Temp (C)', index=weather_df['Date/Time'].dt.month, aggfunc=np.mean)

# %%
mean_temperature_df
# Out:
#             Temp (C)
# Date/Time
# 1          -7.371505
# 2          -4.225000
# 3           3.121237
# 4           7.009306
# 5          16.237769
# 6          20.134028
# 7          22.790054
# 8          22.279301
# 9          16.484444
# 10         10.954973
# 11          0.931389
# 12         -3.306317

# %%
mean_curr_value_df = df_new.pivot_table(values='current_value_eur', index=['potential'], aggfunc=np.mean)

# %%
mean_curr_value_df
# Out:
#            current_value_eur
# potential
# 49              2.500000e+04
# 50              4.000000e+04
# 51              5.571429e+04
# 52              5.223077e+04
# 53              7.205882e+04
# 54              8.140000e+04
# 55              8.900000e+04
# 56              1.005556e+05
# 57              1.213043e+05
# 58              1.321939e+05
# 59              1.646053e+05
# 60              1.811326e+05
# 61              2.205645e+05
# 62              2.691923e+05
# 63              3.379781e+05
# 64              3.912389e+05
# 65              4.668593e+05
# 66              5.612538e+05
# 67              6.500226e+05
# 68              7.376981e+05
# 69              8.464748e+05
# 70              9.502181e+05
# 71              1.108331e+06
# 72              1.360306e+06
# 73              1.663112e+06
# 74              1.903807e+06
# 75              2.448390e+06
# 76              2.844299e+06
# 77              3.608838e+06
# 78              4.975136e+06
# ...

# %%
#group players by their potential
df_new.groupby(df_new['potential']).agg(np.mean)['current_value_eur']
# Out:
# potential
# 49    2.500000e+04
# 50    4.000000e+04
# 51    5.571429e+04
# 52    5.223077e+04
# 53    7.205882e+04
# 54    8.140000e+04
# 55    8.900000e+04
# 56    1.005556e+05
# 57    1.213043e+05
# 58    1.321939e+05
# 59    1.646053e+05
# 60    1.811326e+05
# 61    2.205645e+05
# 62    2.691923e+05
# 63    3.379781e+05
# 64    3.912389e+05
# 65    4.668593e+05
# 66    5.612538e+05
# 67    6.500226e+05
# 68    7.376981e+05
# 69    8.464748e+05
# 70    9.502181e+05
# 71    1.108331e+06
# 72    1.360306e+06
# 73    1.663112e+06
# 74    1.903807e+06
# 75    2.448390e+06
# 76    2.844299e+06
# 77    3.608838e+06
# 78    4.975136e+06
# 79    6.153118e+06
# 80    6.860839e+06
# 81    8.938656e+06
# 82    1.130395e+07
# 83    1.434738e+07
# 84    1.863793e+07
# 85    2.264661e+07
# 86    3.174337e+07
# 87    4.186731e+07
# 88    4.809091e+07
# 89    6.862500e+07
# 90    6.850000e+07
# 91    9.145000e+07
# 92    1.068333e+08
# 93    1.117500e+08
# 95    1.940000e+08
# ...

# %%
#concat, merge, join
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
}, index=[0, 1, 2, 3])

df2 = pd.DataFrame({
    'A': ['A4', 'A5', 'A6', 'A7'],
    'B': ['B4', 'B5', 'B6', 'B7'],
    'C': ['C4', 'C5', 'C6', 'C7'],
    'D': ['D4', 'D5', 'D6', 'D7']
}, index=[4, 5, 6, 7])

df3 = pd.DataFrame({
    'A': ['A8', 'A9', 'A10', 'A11'],
    'B': ['B8', 'B9', 'B10', 'B11'],
    'C': ['C8', 'C9', 'C10', 'C11'],
    'E': ['D8', 'D9', 'D10', 'D11']
}, index=[8, 9, 10, 11])

# %%
pd.concat([df1, df2, df3]) #union
# Out:
#       A    B    C    D    E
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 4    A4   B4   C4   D4  NaN
# 5    A5   B5   C5   D5  NaN
# 6    A6   B6   C6   D6  NaN
# 7    A7   B7   C7   D7  NaN
# 8    A8   B8   C8  NaN   D8
# 9    A9   B9   C9  NaN   D9
# 10  A10  B10  C10  NaN  D10
# 11  A11  B11  C11  NaN  D11

# %%
pd.concat([df1, df2, df3], axis=1) #union
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    E
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
# Join
left_df = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2']
}, index=['K0', 'K1', 'K2']) 

right_df = pd.DataFrame({
    'C': ['C0', 'C2', 'C3'],
    'D': ['D0', 'D2', 'D3']
}, index=['K0', 'K2', 'K3'])

# %%
left_df.join(right_df, how="outer")
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
left_df.join(right_df, how="inner")
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %%
#Merging on multiple keys
left = pd.DataFrame({
    'key1': ['K0', 'K0', 'K1', 'K2'],
    'key2': ['K0', 'K1', 'K0', 'K1'],
    'A': ['A0', 'A1', 'A2', 'A3'],
    'B': ['B0', 'B1', 'B2', 'B3']
})
    
right = pd.DataFrame({
    'key1': ['K0', 'K1', 'K1', 'K2'],
    'key2': ['K0', 'K0', 'K0', 'K0'],
    'C': ['C0', 'C1', 'C2', 'C3'],
    'D': ['D0', 'D1', 'D2', 'D3']
})

# %%
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN
